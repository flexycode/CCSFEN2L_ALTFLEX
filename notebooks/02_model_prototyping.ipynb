# %% [markdown]
# # Model Prototyping
#
# Use this notebook to test new architectures before moving them to `src/models/`.

# %%
from src.models.gnn_analyzer import GNNAnalyzer
from src.models.anomaly_detector import AnomalyDetector

# Initialize models
gnn = GNNAnalyzer()
xgb = AnomalyDetector()
